# %%
! pip list
# Out:
# Package                Version     Location
# ---------------------- ----------- ------------------------------------------
# affine                 2.3.0
# aiobotocore            1.1.1
# aiohttp                3.6.2
# aioitertools           0.7.0
# alembic                1.4.3
# asn1crypto             0.24.0
# async-generator        1.10
# async-timeout          3.0.1
# attrs                  20.2.0
# awscli                 1.18.148
# backcall               0.2.0
# bleach                 3.2.1
# bokeh                  2.2.1
# boto3                  1.15.7
# botocore               1.18.7
# Brotli                 1.0.9
# certifi                2020.6.20
# certipy                0.1.3
# cffi                   1.12.3
# cftime                 1.2.1
# chardet                3.0.4
# click                  7.1.2
# click-plugins          1.1.1
# cligj                  0.5.0
# colorama               0.4.3
# colorcet               2.0.2
# conda                  4.8.1
# ...

# %%
! pip list | grep enduserLib
# Out:
# enduserLib             1.0.0       /home/jupyter-wzell/opt/enduser/enduserLib
