# %%
! ls
# Out:
# 'Small Watersheds 128_Aggregated.cpg'
# 'Small Watersheds 128_Aggregated.dbf'
# 'Small Watersheds 128_Aggregated.prj'
# 'Small Watersheds 128_Aggregated.shp'
# 'Small Watersheds 128_Aggregated.shp.xml'
# 'Small Watersheds 128_Aggregated.shx'
#  Untitled.ipynb
#  mosaicking.ipynb
#  zonalstats.ipynb

# %%
! pwd
# Out:
# /home/jupyter-kagone/postprocess

# %%
! ls .
# Out:
# 'Small Watersheds 128_Aggregated.cpg'
# 'Small Watersheds 128_Aggregated.dbf'
# 'Small Watersheds 128_Aggregated.prj'
# 'Small Watersheds 128_Aggregated.shp'
# 'Small Watersheds 128_Aggregated.shp.xml'
# 'Small Watersheds 128_Aggregated.shx'
#  Untitled.ipynb
#  mosaicking.ipynb
#  zonalstats.ipynb

# %%
! ls /home/jupyter-kagone/postprocess
# Out:
# 'Small Watersheds 128_Aggregated.cpg'
# 'Small Watersheds 128_Aggregated.dbf'
# 'Small Watersheds 128_Aggregated.prj'
# 'Small Watersheds 128_Aggregated.shp'
# 'Small Watersheds 128_Aggregated.shp.xml'
# 'Small Watersheds 128_Aggregated.shx'
#  Untitled.ipynb
#  mosaicking.ipynb
#  zonalmean_2000_2019.csv
#  zonalstats.ipynb

# %%
! grep -i salem ./zonalmean_2000_2019.csv
# Out:
# 51,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 104,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 157,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 210,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 263,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 316,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 369,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 422,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 475,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 528,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 581,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 634,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 687,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# 740,2000,001,etasw,51,Salem River at Woodstown NJ,0.8486120165984171
# ...

# %%
! grep -i salem ./zonalmean_2000_2019.csv | wc -l
# Out:
# 477

# %%
! wc ./zonalmean_2000_2019.csv
# Out:
#   25282  153118 2055764 ./zonalmean_2000_2019.csv

# %%
25282 / 52
# Out:
# 486.1923076923077

# %%
477/3
# Out:
# 159.0

# %%
159/3
# Out:
# 53.0
