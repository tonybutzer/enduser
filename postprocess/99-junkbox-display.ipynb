# %%
# !ls junkbox
# Out:
# dd_avg_200301.tif     ppt_avg_200412.tif  ppt_avg_201007.tif
# dd_avg_200302.tif     ppt_avg_200501.tif  ppt_avg_201008.tif
# etasw_avg_200301.tif  ppt_avg_200502.tif  ppt_avg_201009.tif
# etasw_avg_200302.tif  ppt_avg_200503.tif  ppt_avg_201010.tif
# etasw_avg_200303.tif  ppt_avg_200504.tif  ppt_avg_201011.tif
# etasw_avg_200304.tif  ppt_avg_200505.tif  ppt_avg_201012.tif
# etasw_avg_200305.tif  ppt_avg_200506.tif  ppt_avg_201101.tif
# etasw_avg_200306.tif  ppt_avg_200507.tif  ppt_avg_201102.tif
# etasw_avg_200307.tif  ppt_avg_200508.tif  ppt_avg_201103.tif
# etasw_avg_200308.tif  ppt_avg_200509.tif  ppt_avg_201104.tif
# etasw_avg_200309.tif  ppt_avg_200510.tif  ppt_avg_201105.tif
# etasw_avg_200310.tif  ppt_avg_200511.tif  ppt_avg_201106.tif
# etasw_avg_200311.tif  ppt_avg_200512.tif  ppt_avg_201107.tif
# etasw_avg_200312.tif  ppt_avg_200601.tif  ppt_avg_201108.tif
# etasw_avg_200401.tif  ppt_avg_200602.tif  ppt_avg_201109.tif
# ...

# %%
import xarray as xr
#file = './junkbox/etasw_avg_200301.tif'
file = './junkbox/etasw_avg_200606.tif'
ds = xr.open_rasterio(file)

# %%
ds
# Out:
# <xarray.DataArray (band: 1, y: 3846, x: 2885)>
# [11095710 values with dtype=float32]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 44.0 44.0 44.0 43.99 43.99 ... 36.01 36.0 36.0 36.0
#   * x        (x) float64 -78.0 -78.0 -78.0 -77.99 ... -72.01 -72.0 -72.0 -72.0
# Attributes:
#     transform:      (0.00208048474722841, 0.0, -78.00085750968124, 0.0, -0.00...
#     crs:            +init=epsg:4326
#     res:            (0.00208048474722841, 0.00208048474722841)
#     is_tiled:       0
#     nodatavals:     (nan,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Area

# %%
da=ds.isel(band=0)

# %%
da
# Out:
# <xarray.DataArray (y: 3846, x: 2885)>
# [11095710 values with dtype=float32]
# Coordinates:
#     band     int64 1
#   * y        (y) float64 44.0 44.0 44.0 43.99 43.99 ... 36.01 36.0 36.0 36.0
#   * x        (x) float64 -78.0 -78.0 -78.0 -77.99 ... -72.01 -72.0 -72.0 -72.0
# Attributes:
#     transform:      (0.00208048474722841, 0.0, -78.00085750968124, 0.0, -0.00...
#     crs:            +init=epsg:4326
#     res:            (0.00208048474722841, 0.00208048474722841)
#     is_tiled:       0
#     nodatavals:     (nan,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Area

# %%
da.plot(cmap='viridis')

# %%
da_masked = da.where(da>0.0)

# %%
da_masked.plot(cmap='viridis')

# %%
da_masked
# Out:
# <xarray.DataArray (y: 3846, x: 2885)>
# array([[      nan,       nan,       nan, ..., 4.7567334, 4.835014 ,
#         4.8454514],
#        [      nan,       nan,       nan, ..., 4.8383546, 4.849088 ,
#         4.856272 ],
#        [      nan,       nan,       nan, ..., 4.8472347, 4.8597836,
#         4.868059 ],
#        ...,
#        [4.237575 , 4.156391 , 4.142342 , ...,       nan,       nan,
#               nan],
#        [4.243845 , 4.360251 , 4.3658834, ...,       nan,       nan,
#               nan],
#        [4.299632 , 4.2558236, 4.220109 , ...,       nan,       nan,
#               nan]], dtype=float32)
# Coordinates:
#     band     int64 1
#   * y        (y) float64 44.0 44.0 44.0 43.99 43.99 ... 36.01 36.0 36.0 36.0
#   * x        (x) float64 -78.0 -78.0 -78.0 -77.99 ... -72.01 -72.0 -72.0 -72.0
# Attributes:
#     transform:      (0.00208048474722841, 0.0, -78.00085750968124, 0.0, -0.00...
#     crs:            +init=epsg:4326
# ...

# %%
! df -h .
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/nvme0n1p1  136G   51G   86G  38% /

# %%
file = './junkbox/etasw_avg_200301.tif'

ds = xr.open_rasterio(file)
da=ds.isel(band=0)
da_masked = da.where(da>0.0)
da_masked.plot()
