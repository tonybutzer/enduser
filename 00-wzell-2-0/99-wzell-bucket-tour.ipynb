# %%
! aws s3 ls dev-et-data/
# Out:
#                            PRE /
#                            PRE NA_data_for_cloud/
#                            PRE NDVI_filled/
#                            PRE enduser/
#                            PRE in/
#                            PRE inTest/
#                            PRE incoming/
#                            PRE logan/
#                            PRE out/
#                            PRE raw/
#                            PRE tarballs/
#                            PRE temp/
#                            PRE zarr/
# 2020-05-05 23:59:59         62 Readme-bucket.md
# 2020-09-02 22:08:37     267506 run.log
# 2020-05-05 23:50:00         13 tony.txt

# %%
! aws s3 ls s3://dev-et-data/out/DelawareRiverBasin/Run01_29_2021/run_r-15pct-012921-try5_chip39.84N-73.72E_o/1950/ | grep dd
# Out:
# 2021-01-29 17:33:38    2812812 dd_1950001.tif
# 2021-01-29 17:33:42    2812812 dd_1950002.tif
# 2021-01-29 17:33:45    2812812 dd_1950003.tif
# 2021-01-29 17:33:49    2812812 dd_1950004.tif
# 2021-01-29 17:33:53    2812812 dd_1950005.tif
# 2021-01-29 17:33:57    2812812 dd_1950006.tif
# 2021-01-29 17:34:01    2812812 dd_1950007.tif
# 2021-01-29 17:34:04    2812812 dd_1950008.tif
# 2021-01-29 17:34:08    2812812 dd_1950009.tif
# 2021-01-29 17:35:29    2812812 dd_195001.tif
# 2021-01-29 17:34:12    2812812 dd_1950010.tif
# 2021-01-29 17:34:15    2812812 dd_1950011.tif
# 2021-01-29 17:34:19    2812812 dd_1950012.tif
# 2021-01-29 17:34:22    2812812 dd_1950013.tif
# 2021-01-29 17:34:26    2812812 dd_1950014.tif
# 2021-01-29 17:34:30    2812812 dd_1950015.tif
# 2021-01-29 17:34:33    2812812 dd_1950016.tif
# 2021-01-29 17:34:37    2812812 dd_1950017.tif
# 2021-01-29 17:34:40    2812812 dd_1950018.tif
# 2021-01-29 17:34:44    2812812 dd_1950019.tif
# ...

# %%
! rio info s3://dev-et-data/out/DelawareRiverBasin/Run01_29_2021/run_r-15pct-012921-try5_chip39.84N-73.72E_o/1950/dd_1950003.tif | python -m json.tool
# Out:
# {
#     "bounds": [
#         -73.72346887053719,
#         38.36046748084328,
#         -72.69961838429737,
#         39.846299284044974
#     ],
#     "colorinterp": [
#         "gray"
#     ],
#     "count": 1,
#     "crs": "EPSG:4326",
#     "descriptions": [
#         null
#     ],
#     "driver": "GTiff",
#     "dtype": "float64",
#     "height": 714,
#     "indexes": [
#         1
#     ],
#     "interleave": "band",
#     "lnglat": [
#         -73.21154362741729,
#         39.10338338244413
#     ],
#     "mask_flags": [
#         [
#             "all_valid"
#         ]
#     ],
#     "nodata": null,
#     "res": [
#         0.00208099692325167,
#         0.00208099692325167
#     ],
#     "shape": [
#         714,
#         492
#     ],
#     "tiled": false,
#     "transform": [
#         0.00208099692325167,
#         0.0,
#         -73.72346887053719,
#         0.0,
#         -0.00208099692325167,
#         39.846299284044974,
#         0.0,
#         0.0,
#         1.0
# ...

# %%
! gdalinfo /vsis3/dev-et-data/out/DelawareRiverBasin/Run01_29_2021/run_r-15pct-012921-try5_chip39.84N-73.72E_o/1950/dd_1950003.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /vsis3/dev-et-data/out/DelawareRiverBasin/Run01_29_2021/run_r-15pct-012921-try5_chip39.84N-73.72E_o/1950/dd_1950003.tif
# Size is 492, 714
# Coordinate System is:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433],
#     AUTHORITY["EPSG","4326"]]
# Origin = (-73.723468870537189,39.846299284044974)
# Pixel Size = (0.002080996923252,-0.002080996923252)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  ( -73.7234689,  39.8462993) ( 73d43'24.49"W, 39d50'46.68"N)
# Lower Left  ( -73.7234689,  38.3604675) ( 73d43'24.49"W, 38d21'37.68"N)
# Upper Right ( -72.6996184,  39.8462993) ( 72d41'58.63"W, 39d50'46.68"N)
# Lower Right ( -72.6996184,  38.3604675) ( 72d41'58.63"W, 38d21'37.68"N)
# ...

# %%
# !aws s3 ls dev-et-data/enduser/DelawareRiverBasin/drb150cAnnual/
# Out:
# 2020-12-29 21:12:53    6979950 etasw_1950.tif
# 2020-12-29 21:13:14    6968979 etasw_1951.tif
# 2020-12-29 21:13:36    6984878 etasw_1952.tif
# 2020-12-29 21:13:57    6984577 etasw_1953.tif
# 2020-12-29 21:14:18    6968579 etasw_1954.tif
# 2020-12-29 21:14:40    6963034 etasw_1955.tif
# 2020-12-29 21:15:02    6976513 etasw_1956.tif
# 2020-12-29 21:15:23    6972023 etasw_1957.tif
# 2020-12-29 21:15:44    6962699 etasw_1958.tif
# 2020-12-29 21:16:05    6960658 etasw_1959.tif
# 2020-12-29 21:16:26    6946586 etasw_1960.tif
# 2020-12-29 21:16:47    6955381 etasw_1961.tif
# 2020-12-29 21:17:08    6947502 etasw_1962.tif
# 2020-12-29 21:17:29    6938944 etasw_1963.tif
# 2020-12-29 21:17:50    6966545 etasw_1964.tif
# 2020-12-29 21:18:12    6958417 etasw_1965.tif
# 2020-12-29 21:18:32    6942351 etasw_1966.tif
# 2020-12-29 21:18:53    6959712 etasw_1967.tif
# 2020-12-29 21:19:14    6927867 etasw_1968.tif
# 2020-12-29 21:19:35    6933138 etasw_1969.tif
# ...

# %%
# !gdalinfo /vsis3/dev-et-data/enduser/DelawareRiverBasin/drb150cAnnual/etasw_1958.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /vsis3/dev-et-data/enduser/DelawareRiverBasin/drb150cAnnual/etasw_1958.tif
# Size is 1966, 2139
# Coordinate System is:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433],
#     AUTHORITY["EPSG","4326"]]
# Origin = (-76.789713082482280,38.360944615585886)
# Pixel Size = (0.002079945464631,0.002080031158326)
# Metadata:
#   AREA_OR_POINT=Area
#   grid_mapping=spatial_ref
#   OVR_RESAMPLING_ALG=NEAREST
# Image Structure Metadata:
#   COMPRESSION=DEFLATE
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  ( -76.7897131,  38.3609446) ( 76d47'22.97"W, 38d21'39.40"N)
# Lower Left  ( -76.7897131,  42.8101313) ( 76d47'22.97"W, 42d48'36.47"N)
# Upper Right ( -72.7005403,  38.3609446) ( 72d42' 1.95"W, 38d21'39.40"N)
# ...
